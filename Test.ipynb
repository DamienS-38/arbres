# %%
annees_plantation = {}
annee_actuelle = 2023
annee_debut = annee_actuelle - 19 # Utilisation de range: 19 pour l'année de plantation

for annee in range(annee_debut, annee_actuelle+1):
    annees_plantation[annee] = "Arbre planté"

print(annees_plantation)

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.xlabel('quantité')
plt.show()

# %%
import json
