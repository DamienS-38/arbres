# %%
import pandas as pd
df = pd.read_csv('data/trees.csv', sep=';')

#Afficher les 2 premières lignes
df.head(2)
# Out:
# /tmp/ipykernel_21541/55688228.py:2: DtypeWarning: Columns (22,23,26,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/trees.csv', sep=';')
#    elem_point_id      code      nom genre  genre_desc categorie  \
# 0        27452.0  ESP29627  AR29627   VEG  VEGETATION     ESP01
# 1        27458.0  ESP29628  AR29628   VEG  VEGETATION     ESP01
#
#   categorie_desc sous_categorie      sous_categorie_desc code_parent  ...  \
# 0          Arbre         ESP174  Arbre d'espaces ouverts      ESP991  ...
# 1          Arbre         ESP174  Arbre d'espaces ouverts       ESP22  ...
#
#   diametrearbre  causeabattage       collectivite stationmetro  \
# 0           NaN            NaN  Ville de Grenoble          NaN
# 1           NaN            NaN  Ville de Grenoble          NaN
#
#      hauteurarbre portarbre          structure  forme typenature  \
# 0  de 10 m à 20 m     Libre  Ville de Grenoble   Tige      Libre
# ...

# %%
#Afficher les 2 premières lignes de la 2ème colonne
df.iloc[:2,1]
# Out:
# 0    ESP29627
# 1    ESP29628
# Name: code, dtype: object

# %%
#Afficher les 10 premières lignes année de plantation /Recherche un nom de colonne
df.loc[1:10,['anneedeplantation']]
# Out:
#     anneedeplantation
# 1              1965.0
# 2              1965.0
# 3              1965.0
# 4              1965.0
# 5              2006.0
# 6              1965.0
# 7              1965.0
# 8              1965.0
# 9              1965.0
# 10             1965.0

# %%
df["anneedeplantation"]
# Out:
# 0        1965.0
# 1        1965.0
# 2        1965.0
# 3        1965.0
# 4        1965.0
#           ...
# 31821    1970.0
# 31822    1997.0
# 31823    1960.0
# 31824    1979.0
# 31825    1981.0
# Name: anneedeplantation, Length: 31826, dtype: float64

# %%
#Afficher les 50 premières
#df.head(50)

#Afficher les 50 premières lignes de la colonne  'anneedeplantation'
annee=df.loc[0:49,['anneedeplantation']]
print(annee)

#Afficher les 50 premières lignes des colonnes 'categorie' à 'sous_categorie'
#df.loc[0:49,"categorie":"sous_categorie"]

annee.dropna().to_numpy()
# Out:
#     anneedeplantation
# 0              1965.0
# 1              1965.0
# 2              1965.0
# 3              1965.0
# 4              1965.0
# 5              2006.0
# 6              1965.0
# 7              1965.0
# 8              1965.0
# 9              1965.0
# 10             1965.0
# 11             2009.0
# 12             1995.0
# 13             1995.0
# 14             1979.0
# 15             1985.0
# 16             1976.0
# 17             1976.0
# 18             1975.0
# 19             1985.0
# 20             1976.0
# 21             1976.0
# 22             1975.0
# 23             1975.0
# 24             1975.0
# 25             1976.0
# 26             1976.0
# 27             1985.0
# 28             1985.0
# 29             1981.0
# 30             1974.0
# 31             1976.0
# 32             1976.0
# 33             2008.0
# 34             2008.0
# 35             1985.0
# 36             1985.0
# 37             1976.0
# 38             1976.0
# 39             1985.0
# ...

# %%
#Afficher les 50 dernières
df.tail(50)
# Out:
#        elem_point_id      code      nom genre  genre_desc categorie  \
# 31776        23431.0  ESP28726  AR28726   VEG  VEGETATION     ESP01
# 31777        23432.0  ESP28727  AR28727   VEG  VEGETATION     ESP01
# 31778        20039.0  ESP28728  AR28728   VEG  VEGETATION     ESP01
# 31779        20043.0  ESP28729  AR28729   VEG  VEGETATION     ESP01
# 31780        20051.0  ESP28731  AR28731   VEG  VEGETATION     ESP01
# 31781        23811.0  ESP28734  AR28734   VEG  VEGETATION     ESP01
# 31782        23816.0  ESP28735  AR28735   VEG  VEGETATION     ESP01
# 31783        23820.0  ESP28736  AR28736   VEG  VEGETATION     ESP01
# 31784        23839.0  ESP28741  AR28741   VEG  VEGETATION     ESP01
# 31785        23844.0  ESP28742  AR28742   VEG  VEGETATION     ESP01
# 31786        23850.0  ESP28743  AR28743   VEG  VEGETATION     ESP01
# 31787        23862.0  ESP28746  AR28746   VEG  VEGETATION     ESP01
# 31788        23867.0  ESP28747  AR28747   VEG  VEGETATION     ESP01
# ...

# %%
#Exemple d'utilisation len()
len(df)
# Out:
# 31826

# %%
#Nombre d'éléments unique par colonne
df.nunique()
# Out:
# elem_point_id            31817
# code                     31818
# nom                      31817
# genre                        3
# genre_desc                   5
# categorie                    1
# categorie_desc               1
# sous_categorie               4
# sous_categorie_desc          4
# code_parent               1491
# code_parent_desc          1491
# adr_secteur                 11
# bien_reference           31808
# genre_bota                 116
# espece                     283
# variete                    222
# stadededeveloppement         3
# equipe                       0
# remarques                 2978
# anneedeplantation           66
# raisondeplantation           4
# traitementchenilles          3
# courrier                     1
# identifiantplu              63
# typeimplantationplu          5
# intituleprotectionplu        3
# anneeabattage                1
# essouchement                 9
# diametrearbre                9
# causeabattage                0
# ...

# %%
#Afficher le nom des colonnes
print(df.columns.to_list())
print(df.columns)
# Out:
# ['elem_point_id', 'code', 'nom', 'genre', 'genre_desc', 'categorie', 'categorie_desc', 'sous_categorie', 'sous_categorie_desc', 'code_parent', 'code_parent_desc', 'adr_secteur', 'bien_reference', 'genre_bota', 'espece', 'variete', 'stadededeveloppement', 'equipe', 'remarques', 'anneedeplantation', 'raisondeplantation', 'traitementchenilles', 'courrier', 'identifiantplu', 'typeimplantationplu', 'intituleprotectionplu', 'anneeabattage', 'essouchement', 'diametrearbre', 'causeabattage', 'collectivite', 'stationmetro', 'hauteurarbre', 'portarbre', 'structure', 'forme', 'typenature', 'geo_point_2d']
# Index(['elem_point_id', 'code', 'nom', 'genre', 'genre_desc', 'categorie',
#        'categorie_desc', 'sous_categorie', 'sous_categorie_desc',
#        'code_parent', 'code_parent_desc', 'adr_secteur', 'bien_reference',
#        'genre_bota', 'espece', 'variete', 'stadededeveloppement', 'equipe',
#        'remarques', 'anneedeplantation', 'raisondeplantation',
# ...

# %%
#Afficher les colonnes genre et anneedeplantation
df[["genre","anneedeplantation"]]
# Out:
#       genre  anneedeplantation
# 0       VEG             1965.0
# 1       VEG             1965.0
# 2       VEG             1965.0
# 3       VEG             1965.0
# 4       VEG             1965.0
# ...     ...                ...
# 31821   VEG             1970.0
# 31822   VEG             1997.0
# 31823   VEG             1960.0
# 31824   VEG             1979.0
# 31825   VEG             1981.0
#
# [31826 rows x 2 columns]

# %%
df.sort_values( by="anneedeplantation")
# Out:
#        elem_point_id      code      nom genre  genre_desc categorie  \
# 26658        43762.0  ESP40152  AR40152   VEG  VEGETATION     ESP01
# 835          40008.0  ESP38795  AR38795   VEG  VEGETATION     ESP01
# 26343        44592.0  ESP40667  AR40667   VEG  VEGETATION     ESP01
# 1879         44599.0  ESP40674  AR40674   VEG  VEGETATION     ESP01
# 26337        44580.0  ESP40655  AR40655   VEG  VEGETATION     ESP01
# ...              ...       ...      ...   ...         ...       ...
# 30267        45901.0  ESP41459  AR41459   VEG  VEGETATION     ESP01
# 30268        45902.0  ESP41460  AR41460   VEG  VEGETATION     ESP01
# 30269        45903.0  ESP41461  AR41461   VEG  VEGETATION     ESP01
# 30270        45904.0  ESP41462  AR41462   VEG  VEGETATION     ESP01
# 30271        45905.0  ESP41463  AR41463   VEG  VEGETATION     ESP01
#
#       categorie_desc sous_categorie        sous_categorie_desc code_parent  \
# ...

# %%
df.shape[0]
len(df)
# Out:
# 31826
