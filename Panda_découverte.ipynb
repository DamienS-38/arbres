# %% [markdown]
# Itération 3: Doc Panda --> Découverte

# %% [markdown]
# read_csv()--> Ok,
# .info() --> Ok,
# .head()--> Ok,
# .tail() --> Ok,
# .value_counts()--> Ok,
# .loc --> Ok,
# .query() --> Ok,
# .drop()--> Ok,
# .to_csv('NewFichier.csv', index=False) --> Ok,
# .sort_values(),
# df.describe(),
# df.isna().sum()

# %%
import pandas as pd
data_pandas = pd.read_csv('data/trees.csv', sep=';')
print(data_pandas[:])
data_pandas.head()
# Out:
#        elem_point_id      code      nom genre  genre_desc  ...   portarbre  \
# 0            27452.0  ESP29627  AR29627   VEG  VEGETATION  ...       Libre
# 1            27458.0  ESP29628  AR29628   VEG  VEGETATION  ...       Libre
# 2            27461.0  ESP29629  AR29629   VEG  VEGETATION  ...       Libre
# 3            27467.0  ESP29630  AR29630   VEG  VEGETATION  ...       Libre
# 4            27470.0  ESP29631  AR29631   VEG  VEGETATION  ...       Libre
# ...              ...       ...      ...   ...         ...  ...         ...
# 31821        27517.0  ESP27738  AR27738   VEG  VEGETATION  ...       Libre
# 31822        27519.0  ESP27739  AR27739   VEG  VEGETATION  ...       Libre
# 31823        27521.0  ESP27740  AR27740   VEG  VEGETATION  ...       Libre
# 31824        27523.0  ESP27741  AR27741   VEG  VEGETATION  ...  Semi-libre
# 31825        27525.0  ESP27742  AR27742   VEG  VEGETATION  ...         NaN
#
#                    structure forme  typenature  \
# ...

# %%
#Affiche le nom des colonnes de data_pandas
test=data_pandas.columns.to_list()
print("ou ici")
print(test)
print("==================================")


print("ici")
test2=data_pandas.value_counts()
print(test2)
print("==================================")
print("la")

#Tri
x=data_pandas.sort_values(by = test,ascending=True)
print(x)
print("==================================")
print("peut-être la")
data_pandas[:]

# %%
data_pandas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31826 entries, 0 to 31825
# Data columns (total 38 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   elem_point_id          31817 non-null  float64
#  1   code                   31826 non-null  object
#  2   nom                    31826 non-null  object
#  3   genre                  31826 non-null  object
#  4   genre_desc             31826 non-null  object
#  5   categorie              31817 non-null  object
#  6   categorie_desc         31817 non-null  object
#  7   sous_categorie         31817 non-null  object
#  8   sous_categorie_desc    31817 non-null  object
#  9   code_parent            31817 non-null  object
#  10  code_parent_desc       31817 non-null  object
#  11  adr_secteur            31808 non-null  float64
#  12  bien_reference         31808 non-null  object
#  13  genre_bota             31001 non-null  object
# ...

# %%
#afficher max 10 colonnes
pd.set_option('display.max_columns',10)

df=data_pandas

data_pandas[:1000]
# Out:
#      elem_point_id      code      nom genre  genre_desc  ... portarbre  \
# 0          27452.0  ESP29627  AR29627   VEG  VEGETATION  ...     Libre
# 1          27458.0  ESP29628  AR29628   VEG  VEGETATION  ...     Libre
# 2          27461.0  ESP29629  AR29629   VEG  VEGETATION  ...     Libre
# 3          27467.0  ESP29630  AR29630   VEG  VEGETATION  ...     Libre
# 4          27470.0  ESP29631  AR29631   VEG  VEGETATION  ...     Libre
# ..             ...       ...      ...   ...         ...  ...       ...
# 995        36235.0  ESP36941  AR36941   VEG  VEGETATION  ...       NaN
# 996        36236.0  ESP36942  AR36942   VEG  VEGETATION  ...       NaN
# 997        36237.0  ESP36943  AR36943   VEG  VEGETATION  ...       NaN
# 998        36239.0  ESP36945  AR36945   VEG  VEGETATION  ...       NaN
# 999        36240.0  ESP36946  AR36946   VEG  VEGETATION  ...       NaN
#
#                  structure forme typenature  \
# 0        Ville de Grenoble  Tige      Libre
# ...

# %%
#Affiche les 10 premières lignes (5 par défaut)
df.head(10)
# Out:
#    elem_point_id      code      nom genre  genre_desc  ... portarbre  \
# 0        27452.0  ESP29627  AR29627   VEG  VEGETATION  ...     Libre
# 1        27458.0  ESP29628  AR29628   VEG  VEGETATION  ...     Libre
# 2        27461.0  ESP29629  AR29629   VEG  VEGETATION  ...     Libre
# 3        27467.0  ESP29630  AR29630   VEG  VEGETATION  ...     Libre
# 4        27470.0  ESP29631  AR29631   VEG  VEGETATION  ...     Libre
# 5        27479.0  ESP29633  AR29633   VEG  VEGETATION  ...     Libre
# 6        27488.0  ESP29635  AR29635   VEG  VEGETATION  ...     Libre
# 7        27500.0  ESP29638  AR29638   VEG  VEGETATION  ...       NaN
# 8        27509.0  ESP29640  AR29640   VEG  VEGETATION  ...       NaN
# 9        27514.0  ESP29641  AR29641   VEG  VEGETATION  ...       NaN
#
#            structure forme typenature                           geo_point_2d
# 0  Ville de Grenoble  Tige      Libre    45.18599541005583,5.736390702744254
# ...

# %%
#Affiche les 10 dernières lignes (5 par défaut)
df.tail(10)
# Out:
#        elem_point_id      code      nom genre  genre_desc  ...   portarbre  \
# 31816        27494.0  ESP27733  AR27733   VEG  VEGETATION  ...       Libre
# 31817        27499.0  ESP27734  AR27734   VEG  VEGETATION  ...  Semi-libre
# 31818        27503.0  ESP27735  AR27735   VEG  VEGETATION  ...         NaN
# 31819        27508.0  ESP27736  AR27736   VEG  VEGETATION  ...         NaN
# 31820        27513.0  ESP27737  AR27737   VEG  VEGETATION  ...       Libre
# 31821        27517.0  ESP27738  AR27738   VEG  VEGETATION  ...       Libre
# 31822        27519.0  ESP27739  AR27739   VEG  VEGETATION  ...       Libre
# 31823        27521.0  ESP27740  AR27740   VEG  VEGETATION  ...       Libre
# 31824        27523.0  ESP27741  AR27741   VEG  VEGETATION  ...  Semi-libre
# 31825        27525.0  ESP27742  AR27742   VEG  VEGETATION  ...         NaN
#
#                    structure forme  typenature  \
# 31816      Ville de Grenoble   NaN       Libre
# ...

# %%
df.sample(n=3)
# Out:
#        elem_point_id      code      nom genre  genre_desc  ... portarbre  \
# 23818        46140.0  ESP41626  AR41626   VEG  VEGETATION  ...       NaN
# 23184        25985.0  ESP22481  AR22481   VEG  VEGETATION  ...       NaN
# 492          47487.0  ESP42990  AR42990   VEG  VEGETATION  ...       NaN
#
#                    structure forme typenature  \
# 23818                    NaN   NaN        NaN
# 23184      Ville de Grenoble   NaN        NaN
# 492    Métropole de Grenoble   NaN        NaN
#
#                                geo_point_2d
# 23818   45.1715286465967,5.7416396370055605
# 23184  45.173797322659745,5.742553343395587
# 492     45.16405017798928,5.731976337216879
#
# [3 rows x 38 columns]

# %%
#Affiche le nom des colonnes de data_pandas
colonnes=data_pandas.columns.to_list()
print(colonnes)
# Out:
# ['elem_point_id', 'code', 'nom', 'genre', 'genre_desc', 'categorie', 'categorie_desc', 'sous_categorie', 'sous_categorie_desc', 'code_parent', 'code_parent_desc', 'adr_secteur', 'bien_reference', 'genre_bota', 'espece', 'variete', 'stadededeveloppement', 'equipe', 'remarques', 'anneedeplantation', 'raisondeplantation', 'traitementchenilles', 'courrier', 'identifiantplu', 'typeimplantationplu', 'intituleprotectionplu', 'anneeabattage', 'essouchement', 'diametrearbre', 'causeabattage', 'collectivite', 'stationmetro', 'hauteurarbre', 'portarbre', 'structure', 'forme', 'typenature', 'geo_point_2d']

# %%
col = colonnes
print(df[col].head())
df['code'].head
# Out:
#    elem_point_id      code      nom genre  genre_desc  ... portarbre  \
# 0        27452.0  ESP29627  AR29627   VEG  VEGETATION  ...     Libre
# 1        27458.0  ESP29628  AR29628   VEG  VEGETATION  ...     Libre
# 2        27461.0  ESP29629  AR29629   VEG  VEGETATION  ...     Libre
# 3        27467.0  ESP29630  AR29630   VEG  VEGETATION  ...     Libre
# 4        27470.0  ESP29631  AR29631   VEG  VEGETATION  ...     Libre
#
#            structure forme typenature                           geo_point_2d
# 0  Ville de Grenoble  Tige      Libre    45.18599541005583,5.736390702744254
# 1  Ville de Grenoble   NaN      Libre    45.18535720117796,5.737112737684537
# 2  Ville de Grenoble   NaN      Libre  45.185699673347614,5.7377442387742645
# 3  Ville de Grenoble   NaN      Libre  45.184868969286526,5.7364435192678584
# 4  Ville de Grenoble  Tige      Libre    45.18493170028907,5.734850190386917
#
# [5 rows x 38 columns]
# <bound method NDFrame.head of 0        ESP29627
# ...

# %%
# value at index label 8
df.loc[1:3,['code','nom']]
# Out:
#        code      nom
# 1  ESP29628  AR29628
# 2  ESP29629  AR29629
# 3  ESP29630  AR29630

# %%
# value at index location 29635, afficher les colonnes 2 et 3
df.iloc[1:150,1:3]

df.iloc[:1000,[0,1,2,13]]
# Out:
#      elem_point_id      code      nom  genre_bota
# 0          27452.0  ESP29627  AR29627      Ginkgo
# 1          27458.0  ESP29628  AR29628    Platanus
# 2          27461.0  ESP29629  AR29629       Morus
# 3          27467.0  ESP29630  AR29630       Taxus
# 4          27470.0  ESP29631  AR29631        Acer
# ..             ...       ...      ...         ...
# 995        36235.0  ESP36941  AR36941    Fraxinus
# 996        36236.0  ESP36942  AR36942    Fraxinus
# 997        36237.0  ESP36943  AR36943    Fraxinus
# 998        36239.0  ESP36945  AR36945        Acer
# 999        36240.0  ESP36946  AR36946  Pterocarya
#
# [1000 rows x 4 columns]

# %%
df['code'].value_counts()
# Out:
# code
# 1           9
# ESP29627    1
# ESP30464    1
# ESP30482    1
# ESP30480    1
#            ..
# ESP13408    1
# ESP13407    1
# ESP13406    1
# ESP13404    1
# ESP27742    1
# Name: count, Length: 31818, dtype: int64

# %%
len(df)
# Out:
# 31826

# %%
#Affiche la 19ème colonne
df.columns[35]
# Out:
# 'forme'

# %% [markdown]
# Rename Colonne/ index

# %%
new_df = df.rename(columns={'code':'codes'})

df.rename(index={0: "x"})
new_df[:1000]
# Out:
#      elem_point_id     codes      nom genre  genre_desc  ... portarbre  \
# 0          27452.0  ESP29627  AR29627   VEG  VEGETATION  ...     Libre
# 1          27458.0  ESP29628  AR29628   VEG  VEGETATION  ...     Libre
# 2          27461.0  ESP29629  AR29629   VEG  VEGETATION  ...     Libre
# 3          27467.0  ESP29630  AR29630   VEG  VEGETATION  ...     Libre
# 4          27470.0  ESP29631  AR29631   VEG  VEGETATION  ...     Libre
# ..             ...       ...      ...   ...         ...  ...       ...
# 995        36235.0  ESP36941  AR36941   VEG  VEGETATION  ...       NaN
# 996        36236.0  ESP36942  AR36942   VEG  VEGETATION  ...       NaN
# 997        36237.0  ESP36943  AR36943   VEG  VEGETATION  ...       NaN
# 998        36239.0  ESP36945  AR36945   VEG  VEGETATION  ...       NaN
# 999        36240.0  ESP36946  AR36946   VEG  VEGETATION  ...       NaN
#
#                  structure forme typenature  \
# 0        Ville de Grenoble  Tige      Libre
# ...

# %% [markdown]
# Loc --> Label-location based indexer for selection by label

# %%
print(df.loc)

#Afficher certaines colonnes (code, nom) pour certaines lignes (2 et 1000) du fichier 
df.loc[[2,1000],['code','nom']]
# Out:
# ...
#           code      nom
# 2     ESP29629  AR29629
# 1000  ESP25898  AR25898

# %% [markdown]
# Supprimer colonne --> Ne fonctionne pas
# Change le type de la colonne df[nom_colonne].astype(int)

# %%
#list_of_cols_to_drop={'forme'}
#df.drop(columns = list_of_cols_to_drop)
#df.drop('forme',axis=1, inplace=True)

#df.set_index('forme')
#Ne modifie pas le fichier
df
# Out:
#        elem_point_id      code      nom genre  genre_desc  ...   portarbre  \
# 0            27452.0  ESP29627  AR29627   VEG  VEGETATION  ...       Libre
# 1            27458.0  ESP29628  AR29628   VEG  VEGETATION  ...       Libre
# 2            27461.0  ESP29629  AR29629   VEG  VEGETATION  ...       Libre
# 3            27467.0  ESP29630  AR29630   VEG  VEGETATION  ...       Libre
# 4            27470.0  ESP29631  AR29631   VEG  VEGETATION  ...       Libre
# ...              ...       ...      ...   ...         ...  ...         ...
# 31821        27517.0  ESP27738  AR27738   VEG  VEGETATION  ...       Libre
# 31822        27519.0  ESP27739  AR27739   VEG  VEGETATION  ...       Libre
# 31823        27521.0  ESP27740  AR27740   VEG  VEGETATION  ...       Libre
# 31824        27523.0  ESP27741  AR27741   VEG  VEGETATION  ...  Semi-libre
# 31825        27525.0  ESP27742  AR27742   VEG  VEGETATION  ...         NaN
#
#                    structure forme  typenature  \
# ...

# %%
df.columns
# Out:
# Index(['elem_point_id', 'code', 'nom', 'genre', 'genre_desc', 'categorie',
#        'categorie_desc', 'sous_categorie', 'sous_categorie_desc',
#        'code_parent', 'code_parent_desc', 'adr_secteur', 'bien_reference',
#        'genre_bota', 'espece', 'variete', 'stadededeveloppement', 'equipe',
#        'remarques', 'anneedeplantation', 'raisondeplantation',
#        'traitementchenilles', 'courrier', 'identifiantplu',
#        'typeimplantationplu', 'intituleprotectionplu', 'anneeabattage',
#        'essouchement', 'diametrearbre', 'causeabattage', 'collectivite',
#        'stationmetro', 'hauteurarbre', 'portarbre', 'structure', 'forme',
#        'typenature', 'geo_point_2d'],
#       dtype='object')

# %%
df.query('code < nom')

#Différent
df[df.code < df.nom]
# Out:
#       elem_point_id code      nom    genre  genre_desc  ... portarbre  \
# 1406            NaN    1  AR42084  Quercus  imbricaria  ...       NaN
# 1408            NaN    1  AR42085    Alnus    spaethii  ...       NaN
# 1410            NaN    1  AR42086    Alnus    spaethii  ...       NaN
# 1412            NaN    1  AR42087    Alnus     cordata  ...       NaN
# 1414            NaN    1  AR42088    Alnus    spaethii  ...       NaN
# 1416            NaN    1  AR42089    Alnus     cordata  ...       NaN
# 1815            NaN    1  AR42081  Quercus      cerris  ...       NaN
# 1817            NaN    1  AR42082  Quercus  imbricaria  ...       NaN
# 1819            NaN    1  AR42083  Quercus      cerris  ...       NaN
#
#      structure forme typenature geo_point_2d
# 1406       NaN   NaN        NaN          NaN
# 1408       NaN   NaN        NaN          NaN
# 1410       NaN   NaN        NaN          NaN
# 1412       NaN   NaN        NaN          NaN
# ...

# %%
import pandas as pd1

df1 = pd.DataFrame({'a': ['foo', 'bar'], 'b': [1, 2]})

df2 = pd.DataFrame({'a': ['foo', 'baz'], 'c': [3, 4]})


result = df1.merge(df2, how='outer', on='a')
#result = dft.query('`code` > `nom`')
print(result)
#dft[dft.code > dft.nom]
# Out:
#      a    b    c
# 0  bar  2.0  NaN
# 1  baz  NaN  4.0
# 2  foo  1.0  3.0

# %%
#exporter dans un fichier csv la DataFrame
#df.to_csv('test.csv',index=False)
df
# Out:
#        elem_point_id      code      nom genre  genre_desc  ...   portarbre  \
# 0            27452.0  ESP29627  AR29627   VEG  VEGETATION  ...       Libre
# 1            27458.0  ESP29628  AR29628   VEG  VEGETATION  ...       Libre
# 2            27461.0  ESP29629  AR29629   VEG  VEGETATION  ...       Libre
# 3            27467.0  ESP29630  AR29630   VEG  VEGETATION  ...       Libre
# 4            27470.0  ESP29631  AR29631   VEG  VEGETATION  ...       Libre
# ...              ...       ...      ...   ...         ...  ...         ...
# 31821        27517.0  ESP27738  AR27738   VEG  VEGETATION  ...       Libre
# 31822        27519.0  ESP27739  AR27739   VEG  VEGETATION  ...       Libre
# 31823        27521.0  ESP27740  AR27740   VEG  VEGETATION  ...       Libre
# 31824        27523.0  ESP27741  AR27741   VEG  VEGETATION  ...  Semi-libre
# 31825        27525.0  ESP27742  AR27742   VEG  VEGETATION  ...         NaN
#
#                    structure forme  typenature  \
# ...

# %% [markdown]
# Trier des DataFrames

# %%
data_sorted = df.sort_values(['code','nom'], ascending=True)
print(data_sorted[['code','nom']].head(10))

data_sorted2 = df.sort_values(['code','nom'], ascending=False)
data_sorted2[['code','nom']].head(10)
# Out:
#           code      nom
# 1815         1  AR42081
# 1817         1  AR42082
# 1819         1  AR42083
# 1406         1  AR42084
# 1408         1  AR42085
# 1410         1  AR42086
# 1412         1  AR42087
# 1414         1  AR42088
# 1416         1  AR42089
# 9597  ESP10001  AR10001
#          code     nom
# 9596  ESP9999  AR9999
# 9595  ESP9998  AR9998
# 9594  ESP9997  AR9997
# 9593  ESP9996  AR9996
# 9592  ESP9995  AR9995
# 9591  ESP9994  AR9994
# 9516  ESP9993  AR9993
# 9515  ESP9992  AR9992
# 9514  ESP9991  AR9991
# 9513  ESP9990  AR9990

# %% [markdown]
# Group By --> Grouper par 'colonne'
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html

# %%
df.describe()
# Out:
#        elem_point_id   adr_secteur  equipe  anneedeplantation  essouchement  \
# count   31817.000000  31808.000000     0.0       29828.000000      9.000000
# mean    20790.957884    492.367046     NaN        1990.105136     45.196310
# std     13078.555801   4296.699452     NaN          17.982968      0.000163
# min         1.000000      1.000000     NaN        1900.000000     45.196078
# 25%      9805.000000      2.000000     NaN        1975.000000     45.196181
# 50%     19716.000000      4.000000     NaN        1987.000000     45.196331
# 75%     29703.000000      5.000000     NaN        2006.000000     45.196434
# max     47913.000000  38421.000000     NaN        2022.000000     45.196540
#
#        causeabattage
# count            0.0
# mean             NaN
# std              NaN
# min              NaN
# 25%              NaN
# 50%              NaN
# 75%              NaN
# max              NaN

# %%
df.isna().sum()
# Out:
# elem_point_id                9
# code                         0
# nom                          0
# genre                        0
# genre_desc                   0
# categorie                    9
# categorie_desc               9
# sous_categorie               9
# sous_categorie_desc          9
# code_parent                  9
# code_parent_desc             9
# adr_secteur                 18
# bien_reference              18
# genre_bota                 825
# espece                    2488
# variete                  27185
# stadededeveloppement      3873
# equipe                   31826
# remarques                26520
# anneedeplantation         1998
# raisondeplantation       28516
# traitementchenilles      29730
# courrier                 31817
# identifiantplu           31223
# typeimplantationplu      26788
# intituleprotectionplu    31232
# anneeabattage            31817
# essouchement             31817
# diametrearbre            31817
# causeabattage            31826
# ...

# %%
list_of_cols=['nom','code']
df.sort_values(by=list_of_cols,ascending=True)
# Out:
#       elem_point_id      code      nom genre  genre_desc  ...   portarbre  \
# 9597          309.0  ESP10001  AR10001   VEG  VEGETATION  ...  Semi-libre
# 9598          311.0  ESP10002  AR10002   VEG  VEGETATION  ...         NaN
# 9599          313.0  ESP10003  AR10003   VEG  VEGETATION  ...         NaN
# 9600          315.0  ESP10004  AR10004   VEG  VEGETATION  ...       Libre
# 9601          317.0  ESP10005  AR10005   VEG  VEGETATION  ...         NaN
# ...             ...       ...      ...   ...         ...  ...         ...
# 9592          298.0   ESP9995   AR9995   VEG  VEGETATION  ...         NaN
# 9593          300.0   ESP9996   AR9996   VEG  VEGETATION  ...         NaN
# 9594          302.0   ESP9997   AR9997   VEG  VEGETATION  ...         NaN
# 9595          304.0   ESP9998   AR9998   VEG  VEGETATION  ...         NaN
# 9596          306.0   ESP9999   AR9999   VEG  VEGETATION  ...         NaN
#
#                   structure forme  typenature  \
# ...

# %%
df.sort_values( by="anneedeplantation")

df[df.anneedeplantation < 1955]
#df[df.ANNEEDEPLANTATION.isin([1960, 1970])]
#df[(df.ANNEEDEPLANTATION == 1960) | (df.ANNEEDEPLANTATION == 1970) ]
# Out:
#        elem_point_id      code      nom genre  genre_desc  ...     portarbre  \
# 835          40008.0  ESP38795  AR38795   VEG  VEGETATION  ...           NaN
# 841          11908.0  ESP25672  AR25672   VEG  VEGETATION  ...    Semi-libre
# 1050          1248.0  ESP30114  AR30114   VEG  VEGETATION  ...    Semi-libre
# 1074           468.0  ESP30146  AR30146   VEG  VEGETATION  ...  Architecturé
# 1078           490.0  ESP30151  AR30151   VEG  VEGETATION  ...    Semi-libre
# ...              ...       ...      ...   ...         ...  ...           ...
# 31566         8067.0  ESP28332  AR28332   VEG  VEGETATION  ...    Semi-libre
# 31584        23194.0  ESP28660  AR28660   VEG  VEGETATION  ...    Semi-libre
# 31614        15569.0  ESP27664  AR27664   VEG  VEGETATION  ...  Architecturé
# 31618        15587.0  ESP27668  AR27668   VEG  VEGETATION  ...    Semi-libre
# 31816        27494.0  ESP27733  AR27733   VEG  VEGETATION  ...         Libre
#
# ...

# %%
resultat=df.groupby(by=['code']).sum()
print(resultat)
df
# Out:
#           elem_point_id                                                nom  \
# code
# 1                   0.0  AR42084AR42085AR42086AR42087AR42088AR42089AR42...
# ESP10001          309.0                                            AR10001
# ESP10002          311.0                                            AR10002
# ESP10003          313.0                                            AR10003
# ESP10004          315.0                                            AR10004
# ...                 ...                                                ...
# ESP9995           298.0                                             AR9995
# ESP9996           300.0                                             AR9996
# ESP9997           302.0                                             AR9997
# ESP9998           304.0                                             AR9998
# ESP9999           306.0                                             AR9999
#
# ...
